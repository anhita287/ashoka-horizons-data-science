# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np
df = pd.read_csv('nutrition-food.csv',names=['Food Item', 'Calories', 'Fat (g)', 'Carbs (g)', 'Protein (g)', 'Fiber (g)'], encoding='utf-16', header=None)
print(df)

#Question 1

print("Top 5 entries for nutrition-foods:")
print(df.head(5))

print("Bottom 5 entries for foods:")
print(df.tail(5))

print("Number of columns and rows")
print(df.shape)

print("Unique entries and their counts")
for col in df.columns:
    unique_entries = df[col].unique()
    num_unique_entries = df[col].nunique()
    print("Num of unique entries:")
    print(num_unique_entries)
    print(unique_entries)

#Question 2
df2=pd.read_csv('nutrition-food.csv', skiprows=1, encoding='utf-16')
print (df2.dtypes)

##| Column Name    | Data Type | Classification | Explanation                                                                                     |

##| Chonga Bagel   | object    | Nominal        | Represents a categorical variable with no inherent order, typical of nominal data.            |
##| 300            | int64     | Discrete       | Represents a countable variable with distinct values, indicating discrete quantities.          |
##| 5              | float64   | Continuous     | Represents a variable that can take on any value within a given range, typical of continuous data. |
##| 50             | int64     | Discrete       | Represents a countable variable with distinct values, indicating discrete quantities.          |
##| 3              | int64     | Discrete       | Represents a countable variable with distinct values, indicating discrete quantities.          |
##| 12             | int64     | Discrete       | Represents a countable variable with distinct values, indicating discrete quantities.          |

#Question3
null_values_per_column = df2.isnull().sum()
df_new = df2.dropna()
print("Null values in each column:")
print(null_values_per_column)
print(df_new)

#Question 4
df.rename(columns={'Fat (g)': 'Fat', 'Carbs (g)': 'Carb', 'Fiber (g)': 'Fiber'}, inplace=True)
df.drop(columns=['Calories', 'Protein (g)'], inplace=True)


## We might choose to drop the 'Calories' column if we're not interested in analyzing calorie content or if it's redundant with other nutritional information. For example, if we're focusing on macronutrients like fat, carbohydrates, and protein, we might not need to consider total calorie content separately.
##Similar to the 'Calories' column, we might choose to drop the 'Protein (g)' column if we're not specifically interested in protein content or if it's redundant with other information. If our analysis focuses on other aspects of nutrition or if protein content is not a significant factor for our analysis, we might opt to exclude this column to simplify our datas

#Question 5
df_n=pd.read_csv('nutrition-food.csv', header=0, encoding="utf-16")
print(df['Fat'].min())
print(df['Fat'].max())
print(df['Fat'].sum())
print(df['Fat'].mean())
print(df['Fat'].std())
print(df['Fat'].var())


#Question 6
import numpy as np
num_samples = len(df)
subset_size = int(0.25 * num_samples)

for i in range(4):
    random_indices = np.random.choice(num_samples, size=subset_size, replace=False)
    random_subset = df.iloc[random_indices]


    if i == 0:
        df1 = random_subset.copy()
    elif i == 1:
        df22 = random_subset[~random_subset.index.isin(df1.index)].copy()
    elif i == 2:
        df33 = random_subset[~random_subset.index.isin(pd.concat([df1, df22]).index)].copy()
    else:
        df4 = random_subset[~random_subset.index.isin(pd.concat([df1, df22, df33]).index)].copy()

#Question7
# !pip install matplotlib
# !pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
fat = df['Fat'].values
len(fat)
plt.hist(fat, bins=10)
sns.boxplot(fat)
carbs=df['Carb'].values
len(carbs)
plt.hist(carbs, bins=10)
sns.boxplot(carbs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1691         try:
# -> 1692             x = float(x)
#    1693         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: ' Fat (g)56222322161712221651521182224151162315232428233.53.5385142010412182721184.51.5151718917176981318211425141812232913378726322918282923162722242612989919132.527172.56281823227301019172725271720291821232.52.514181380'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1695             try:
# -> 1696                 x = complex(x)
#    1697             except ValueError as err:
#
# ...
