# %%
# !pip install pandas
# !pip install numpy

# !pip install matplotlib
# !pip install seaborn
# !pip install plotly

import pandas as pd
import numpy as np

df= pd.read_csv('nutrition-drinks1.csv')

print("Top 5 entries:")
print (df.head(5))

print(df.dtypes)

print("Bottom 5 entries:")
print (df.tail(5))

import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py

#Line Graph
plt.title(' Line Graph ')
plt.xlabel('Unnamed: 0', fontsize=15)
plt.ylabel('Calories', fontsize=15)
plt.plot(df['Unnamed: 0'], df['Fiber (g)'],marker='o', color='blue',markeredgewidth='0.5', markeredgecolor='black', markerfacecolor='green')
plt.xticks(rotation=75, ha='right') # to prevent overlaping of text
plt.figure(figsize=(160, 160))

#Bar plot
beverage_category_unique = df['Unnamed: 0'].unique()
values = df['Unnamed: 0'].value_counts().to_list()
plt.bar(x=beverage_category_unique, height=values)
plt.xticks(rotation=60, ha='right') # to prevent overlaping of text
plt.xlabel('Beverage Category')
plt.ylabel('Counts')
plt.title('Counts of Each Beverage Category')

#Boxplot

sns.boxplot(data=df[['Calories', 'Carb. (g)']], color='orange')

#Count plot
sns.countplot(x='Unnamed: 0', data=df.reset_index())
plt.xticks(rotation=60, ha='right') # to prevent overlaping of text
plt.title('Counts of Each Beverage Preparation')

#Scatter plot
sns.scatterplot(df[['Protein', 'Sodium']], edgecolor='black')

#3D Scatter Plot
df.replace('-', np.nan, inplace=True)
numeric_columns = ['Calories']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
df_cleaned = df.dropna()
from mpl_toolkits.mplot3d import Axes3D
data = df_cleaned[['Sodium', 'Carb. (g)']]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data['Sodium'], data['Carb. (g)'])
plt.show()

#Bubble scatter
plt.scatter(df['Calories'], df['Sodium'], s=df['Fat (g)'], edgecolor='black')

#Histogram
plt.hist(df['Unnamed: 0'], bins=10, edgecolor='black')

#Violin plot
sns.violinplot(data=df[['Sodium', 'Calories']])

#heatmap
crr_ = df[['Carb. (g)', 'Fat (g)', 'Sodium', 'Fiber (g)']].corr()
sns.heatmap(crr_, cmap='coolwarm', annot=True)

#KDE Plot
sns.kdeplot(df['Calories'])

plt.figure(figsize=(10,5))
sns.distplot(df['Protein'], bins=10, kde=True, color='#0f5a3e')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.title('Count of Categories', fontsize=20, color='Blue')
plt.show()

# !pip install wordcloud

from wordcloud import WordCloud

all_words = ' '.join(df['Unnamed: 0'].dropna().astype(str).tolist())

plt.figure(figsize=(10,5))
wordcloud = WordCloud(width=800, height=400, background_color='grey').generate(all_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('WordCloud', fontsize=15, color='blue')
plt.axis('off')
plt.show()

#jointplot
df['Calories'] = pd.to_numeric(df['Calories'].replace('-', np.nan), errors='coerce')
df['Protein'] = pd.to_numeric(df['Protein'].replace('-', np.nan), errors='coerce')
df_cleaned = df.dropna(subset=['Protein', 'Calories'])
sns.jointplot(data=df_cleaned, x='Protein', y='Calories', kind='hex', color='#0f5a3e')
plt.xlabel('Calories')
plt.ylabel('Protein')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.show()

# !pip install scipy
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import fcluster
from scipy.spatial.distance import pdist
import numpy as np

df_plot=(df.drop('Unnamed: 0', axis=1))
plt.figure(figsize=(10,5))
link = linkage(df_plot, 'ward')
dendrogram(link, color_threshold=5, truncate_mode='lastp', p=10)
plt.xticks(rotation=90)
plt.title('Dendrogram Plot', fontsize=20, color='red')
plt.show()

plt.figure(figsize=(10,5))
sns.clustermap(df_plot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-01e20e1667f4> in <cell line: 2>()
#       1 plt.figure(figsize=(10,5))
# ----> 2 link = linkage(df_plot, 'ward')
#       3 dendrogram(link, color_threshold=5, truncate_mode='lastp', p=10)
#       4 plt.xticks(rotation=90)
#       5 plt.title('Dendrogram Plot', fontsize=20, color='red')
#
# /usr/local/lib/python3.10/dist-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1062
#    1063     if not np.all(np.isfinite(y)):
# -> 1064         raise ValueError("The condensed distance matrix must contain only "
#    1065                          "finite values.")
#    1066
#
# ValueError: The condensed distance matrix must contain only finite values.
